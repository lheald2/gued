# %% [markdown]
# # Processing Hot Structure Files

# %% [markdown]
# Made for processing hot structures of a fragmentation channel for the QC experiment. Need to adapt for future implementation

# %%
import numpy as np
import gued_theory as gt
import matplotlib.pyplot as plt
import glob
import pandas as pd

# %matplotlib widget

# %% [markdown]
# ## Load Hot structures
# Takes approx 1 min

# %%
file_path = "C:\\Users\\laure\\OneDrive - University of Nebraska-Lincoln\\Documents\\Centurion Lab\\QC data and code\\hot_structures\\"
file_names = ["ethanol", "CP", "NBD", "QC"]
file_type = ".xyz"


structure_dict = {key: {"coordinates": [], "atom_sums": [],} for key in file_names}

for file_name in file_names:
    coors, atom_sum = gt.load_hot_xyz(file_path, file_name, file_type)
    structure_dict[file_name]["coordinates"] = coors
    structure_dict[file_name]["atom_sums"] = atom_sum

# %% [markdown]
# ## Get I for all hot structurs and find mean
# Takes ~ 15 minutes

# %%
I_totals = {key: [] for key in file_names}
I_stds = {key: [] for key in file_names}

for key in file_names:
    print(f"Calculating I total for all {key} structures")
    all_I = []
    count = 0
    for structure in structure_dict[key]["coordinates"]:
        I_tot, I_at, I_mol, s_temp = gt.get_I_xray(structure, structure_dict[key]['atom_sums'])
        all_I.append(np.array(I_tot))
        count+=1 
        if count%1000 == 0:
            print(f"Processed {count}")
    I_totals[key] = np.mean(all_I, axis=0)
    I_stds[key] = np.std(all_I, axis=0)
# Out:
# Calculating I total for all ethanol structures
# Processed 1000
# Processed 2000
# Processed 3000
# Processed 4000
# Processed 5000
# Processed 6000
# Processed 7000
# Processed 8000
# Processed 9000
# Processed 10000
# Calculating I total for all CP structures
# Processed 1000
# Processed 2000
# Processed 3000
# Processed 4000
# Processed 5000
# Processed 6000
# Processed 7000
# Processed 8000
# Processed 9000
# Processed 10000
# Calculating I total for all NBD structures
# Processed 1000
# Processed 2000
# Processed 3000
# Processed 4000
# Processed 5000
# Processed 6000
# Processed 7000
# Processed 8000
# Processed 9000
# Processed 10000
# Calculating I total for all QC structures
# Processed 1000
# Processed 2000
# Processed 3000
# Processed 4000
# Processed 5000
# Processed 6000
# Processed 7000
# Processed 8000
# Processed 9000
# Processed 10000

# %% [markdown]
# ## Get I0 from Trajectories
# Takes ~ 11 minutes

# %%
# Define the folder path to the trajectory files
ids = ["NB", "QC"]
folders = ["Singlet_2", "Singlet_3", "Singlet_4"]
I0_all = []


def process_trajectory(folder, mol_name, file_type):
    print(f"getting trajectory for {folder[-6:-2]}")
    xyz, at_sum, counts = gt.load_time_evolving_xyz(folder, mol_name, file_type)
    print(at_sum)
    I0, I_at0, I_mol0, _ = gt.get_I_xray(xyz[0], at_sum)
    return I0


path_traj = f"C:/Users/laure/OneDrive - University of Nebraska-Lincoln/Documents/Centurion Lab/QC data and code/Theory Structures/*/*/*/"

traj_folder = glob.glob(path_traj)
# sort the folder names in order of trajectory number

print(f"Processing {len(traj_folder)} trajectory files.")
mol_name = "output"
file_type = ".xyz"
for file in traj_folder:
    I0 = process_trajectory(file, mol_name, file_type)
    I0_all.append(np.array(I0))

I0_all = np.array(I0_all)
print(I0_all.shape)
I0_mean = np.mean(np.array(I0_all), axis=0)
# Out:
# Processing 239 trajectory files.
# getting trajectory for 0008
# 15
# getting trajectory for 0020
# 15
# getting trajectory for 0037
# 15
# getting trajectory for 0068
# 15
# getting trajectory for 0070
# 15
# getting trajectory for 0079
# 15
# getting trajectory for 0090
# 15
# getting trajectory for 0107
# 15
# getting trajectory for 0115
# 15
# getting trajectory for 0128
# 15
# getting trajectory for 0142
# 15
# getting trajectory for 0149
# 15
# getting trajectory for 0236
# 15
# getting trajectory for 0237
# 15
# getting trajectory for 0238
# 15
# getting trajectory for 0267
# 15
# getting trajectory for 0275
# 15
# getting trajectory for 0278
# 15
# getting trajectory for 0285
# 15
# getting trajectory for 0308
# 15
# getting trajectory for 0354
# 15
# getting trajectory for 0372
# 15
# getting trajectory for 0398
# 15
# getting trajectory for 0409
# 15
# getting trajectory for 0489
# 15
# getting trajectory for 0499
# 15
# getting trajectory for 0512
# 15
# getting trajectory for 0516
# 15
# getting trajectory for 0524
# 15
# getting trajectory for 0530
# 15
# getting trajectory for 0541
# 15
# getting trajectory for 0553
# 15
# getting trajectory for 0564
# 15
# getting trajectory for 0565
# 15
# getting trajectory for 0566
# 15
# getting trajectory for 0586
# 15
# getting trajectory for 0592
# 15
# getting trajectory for 0600
# 15
# getting trajectory for 0606
# 15
# getting trajectory for 0609
# 15
# getting trajectory for 0611
# 15
# getting trajectory for 0626
# 15
# getting trajectory for 0639
# 15
# getting trajectory for 0647
# 15
# getting trajectory for 0647
# 15
# getting trajectory for 0663
# 15
# getting trajectory for 0671
# 15
# getting trajectory for 0726
# 15
# getting trajectory for 0731
# 15
# getting trajectory for 0766
# 15
# getting trajectory for 0767
# 15
# getting trajectory for 0771
# 15
# getting trajectory for 0787
# 15
# getting trajectory for 0792
# 15
# getting trajectory for 0795
# 15
# getting trajectory for 0869
# 15
# getting trajectory for 0870
# 15
# getting trajectory for 0895
# 15
# getting trajectory for 0900
# 15
# getting trajectory for 0936
# 15
# getting trajectory for 0965
# 15
# getting trajectory for 0976
# 15
# getting trajectory for 0978
# 15
# getting trajectory for 0000
# 15
# getting trajectory for 0004
# 15
# getting trajectory for 0025
# 15
# getting trajectory for 0046
# 15
# getting trajectory for 0059
# 15
# getting trajectory for 0061
# 15
# getting trajectory for 0068
# 15
# getting trajectory for 0069
# 15
# getting trajectory for 0071
# 15
# getting trajectory for 0074
# 15
# getting trajectory for 0092
# 15
# getting trajectory for 0120
# 15
# getting trajectory for 0158
# 15
# getting trajectory for 0190
# 15
# getting trajectory for 0196
# 15
# getting trajectory for 0264
# 15
# getting trajectory for 0273
# 15
# getting trajectory for 0292
# 15
# getting trajectory for 0307
# 15
# getting trajectory for 0307
# 15
# getting trajectory for 0337
# 15
# getting trajectory for 0339
# 15
# getting trajectory for 0346
# 15
# getting trajectory for 0433
# 15
# getting trajectory for 0453
# 15
# getting trajectory for 0481
# 15
# getting trajectory for 0493
# 15
# getting trajectory for 0501
# 15
# getting trajectory for 0533
# 15
# getting trajectory for 0549
# 15
# getting trajectory for 0599
# 15
# getting trajectory for 0602
# 15
# getting trajectory for 0604
# 15
# getting trajectory for 0656
# 15
# getting trajectory for 0678
# 15
# getting trajectory for 0680
# 15
# getting trajectory for 0690
# 15
# getting trajectory for 0714
# 15
# getting trajectory for 0744
# 15
# getting trajectory for 0754
# 15
# getting trajectory for 0757
# 15
# getting trajectory for 0760
# 15
# getting trajectory for 0780
# 15
# getting trajectory for 0818
# 15
# getting trajectory for 0822
# 15
# getting trajectory for 0822
# 15
# getting trajectory for 0875
# 15
# getting trajectory for 0881
# 15
# getting trajectory for 0883
# 15
# getting trajectory for 0905
# 15
# getting trajectory for 0913
# 15
# getting trajectory for 0914
# 15
# getting trajectory for 0918
# 15
# getting trajectory for 0921
# 15
# getting trajectory for 0921
# 15
# getting trajectory for 0976
# 15
# getting trajectory for 0007
# 15
# getting trajectory for 0039
# 15
# getting trajectory for 0050
# 15
# getting trajectory for 0051
# 15
# getting trajectory for 0132
# 15
# getting trajectory for 0139
# 15
# getting trajectory for 0150
# 15
# getting trajectory for 0152
# 15
# getting trajectory for 0175
# 15
# getting trajectory for 0220
# 15
# getting trajectory for 0222
# 15
# getting trajectory for 0238
# 15
# getting trajectory for 0285
# 15
# getting trajectory for 0297
# 15
# getting trajectory for 0561
# 15
# getting trajectory for 0602
# 15
# getting trajectory for 0603
# 15
# getting trajectory for 0616
# 15
# getting trajectory for 0661
# 15
# getting trajectory for 0674
# 15
# getting trajectory for 0707
# 15
# getting trajectory for 0764
# 15
# getting trajectory for 0790
# 15
# getting trajectory for 0799
# 15
# getting trajectory for 0807
# 15
# getting trajectory for 0830
# 15
# getting trajectory for 0864
# 15
# getting trajectory for 0942
# 15
# getting trajectory for 0943
# 15
# getting trajectory for 0946
# 15
# getting trajectory for 0014
# 15
# getting trajectory for 0050
# 15
# getting trajectory for 0054
# 15
# getting trajectory for 0066
# 15
# getting trajectory for 0091
# 15
# getting trajectory for 0111
# 15
# getting trajectory for 0113
# 15
# getting trajectory for 0152
# 15
# getting trajectory for 0229
# 15
# getting trajectory for 0231
# 15
# getting trajectory for 0294
# 15
# getting trajectory for 0297
# 15
# getting trajectory for 0305
# 15
# getting trajectory for 0326
# 15
# getting trajectory for 0358
# 15
# getting trajectory for 0360
# 15
# getting trajectory for 0404
# 15
# getting trajectory for 0513
# 15
# getting trajectory for 0517
# 15
# getting trajectory for 0532
# 15
# getting trajectory for 0548
# 15
# getting trajectory for 0555
# 15
# getting trajectory for 0603
# 15
# getting trajectory for 0616
# 15
# getting trajectory for 0624
# 15
# getting trajectory for 0693
# 15
# getting trajectory for 0751
# 15
# getting trajectory for 0770
# 15
# getting trajectory for 0785
# 15
# getting trajectory for 0788
# 15
# getting trajectory for 0805
# 15
# getting trajectory for 0869
# 15
# getting trajectory for 0917
# 15
# getting trajectory for 0924
# 15
# getting trajectory for 0957
# 15
# getting trajectory for 0968
# 15
# getting trajectory for 0977
# 15
# getting trajectory for 0999
# 15
# getting trajectory for 0026
# 15
# getting trajectory for 0119
# 15
# getting trajectory for 0210
# 15
# getting trajectory for 0211
# 15
# getting trajectory for 0233
# 15
# getting trajectory for 0254
# 15
# getting trajectory for 0310
# 15
# getting trajectory for 0350
# 15
# getting trajectory for 0352
# 15
# getting trajectory for 0360
# 15
# getting trajectory for 0364
# 15
# getting trajectory for 0400
# 15
# getting trajectory for 0410
# 15
# getting trajectory for 0455
# 15
# getting trajectory for 0535
# 15
# getting trajectory for 0549
# 15
# getting trajectory for 0559
# 15
# getting trajectory for 0614
# 15
# getting trajectory for 0712
# 15
# getting trajectory for 0745
# 15
# getting trajectory for 0756
# 15
# getting trajectory for 0904
# 15
# getting trajectory for 0904
# 15
# getting trajectory for 0921
# 15
# getting trajectory for 0947
# 15
# getting trajectory for 0963
# 15
# getting trajectory for 0058
# 15
# getting trajectory for 0070
# 15
# getting trajectory for 0141
# 15
# getting trajectory for 0278
# 15
# getting trajectory for 0303
# 15
# getting trajectory for 0383
# 15
# getting trajectory for 0392
# 15
# getting trajectory for 0462
# 15
# getting trajectory for 0506
# 15
# getting trajectory for 0512
# 15
# getting trajectory for 0587
# 15
# getting trajectory for 0635
# 15
# getting trajectory for 0641
# 15
# getting trajectory for 0702
# 15
# getting trajectory for 0706
# 15
# getting trajectory for 0725
# 15
# getting trajectory for 0733
# 15
# getting trajectory for 0766
# 15
# getting trajectory for 0769
# 15
# getting trajectory for 0773
# 15
# getting trajectory for 0795
# 15
# getting trajectory for 0828
# 15
# getting trajectory for 0871
# 15
# getting trajectory for 0908
# 15
# getting trajectory for 0920
# 15
# getting trajectory for 0973
# 15
# (239, 500)

# %%
key_words = ["NB", "QC", "frags"]
dI_I_hot = {key: [] for key in key_words}
dI_I_hot["QC"] = (I_totals["QC"]-I0_mean)/I0_mean
dI_I_hot["NB"] = (I_totals["NBD"]-I0_mean)/I0_mean
dI_I_hot["frags"] = ((I_totals["CP"]+I_totals["ethanol"])-I0_mean)/I0_mean

# %%
for key in key_words:
    file_name = key+"_xray.txt"
    frag_dict = {"s_values": s_temp, "dI_I": dI_I_hot[key]}
    frag_df = pd.DataFrame(frag_dict)
    frag_df.to_csv(file_name, sep='\t', index=False)
