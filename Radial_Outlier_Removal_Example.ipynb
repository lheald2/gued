# %%
from tifffile import tifffile as tf

# %%
temp = tf.imread("Masked_ex.tif")

# %%
tf.imshow(temp)
# Out:
# (<Figure size 988.8x604.8 with 2 Axes>,
#  <Axes: >,
#  <matplotlib.image.AxesImage at 0x14c7536b3790>)
